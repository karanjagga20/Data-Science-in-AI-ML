# %% [markdown]
# <a href="https://colab.research.google.com/github/karanjagga20/Data-Science-in-AI-ML/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hi")
# Out:
# hi
